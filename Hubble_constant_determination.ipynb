# %%
import numpy as np
import pandas as pd
x=[22.964509394572, 38.1282495667244, 36.4238410596026, 37.3514431239389, 20.1834862385321, 8.792965627498, 27.5, 26.0663507109005, 79.4223826714801, 21.1538461538462]
y=[2103.43883998379, 1964.15720951459, 2378.37923571308, 890.534970625753, 987.819977822462,240.19567335119, 2463.04895298343, 1239.79704977369, 1307.51351030705, 1056.23301145242]
import matplotlib.pyplot as plt
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
plt.xlabel('Distance in Megaparsecs')
plt.ylabel('Recessional Velocity in km/s')
plt.title('Hubble constant determination')
plt.scatter(x,y)
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt

results = sm.OLS(y,sm.add_constant(x)).fit()
plt.scatter(x,y,color='b')
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)),'b')
plt.savefig('Hubble constant determination',dpi=720,transparent=False,bbox_inches='tight',facecolor='w', edgecolor='w')
plt.show()

# %%
from scipy.stats import linregress
linregress(x, y)
#Slope represents the Hubble constant value
# Out:
# LinregressResult(slope=7.996474453171349, intercept=1208.8342913472918, rvalue=0.20889490321373547, pvalue=0.5624660374131673, stderr=13.235400312189281, intercept_stderr=484.1109367871446)
